# %% [markdown]
#  Author: Lourde Hajjar
#
#  The notebook applies CNN on the Edge-detected image dataset. It preprocesses the data by normalizing images and resizing to 256x256, builds a  (CNN) model, and trains it.
#
#  The model's performance is evaluated using validation accuracy during training and 10-fold cross-validation, achieving outstanding results with accuracy of 97.41%. It also visualizes training progress with loss and accuracy plots.

# %% [markdown]
# # Basic CNN Without Augmentation

# %% [markdown]
# ## Import the Libraries

# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## Load the Edge-detected Dataset

# %%
# Define dataset path
data_dir =r"C:\Users\lourd\OneDrive\Desktop\coursework\datasets\3_image\processed\3_ed_b"


images = []
labels = []



for label in os.listdir(data_dir):
    label_dir = os.path.join(data_dir, label)
    if os.path.isdir(label_dir):
        for img_file in os.listdir(label_dir):
            img_path = os.path.join(label_dir, img_file)
            img = load_img(img_path, color_mode="grayscale")
            img = load_img(img_path, target_size=(256, 256), color_mode="grayscale")
            img_array = img_to_array(img) / 255.0  # Normalize
            images.append(img_array)
            labels.append(label)


images = np.array(images)
labels = np.array(labels)

class_names = ['normal', 'malignant', 'benign']


images = images.reshape(-1, 256, 256, 1)


label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(labels)

# Split data into training and test sets
x_train, x_test, y_train, y_test = train_test_split(images, encoded_labels, test_size=0.2, random_state=42)

# %% [markdown]
# ## Define the CNN Model

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(256, 256, 1)),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 64)      640
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 64)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 64)      36928
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 246016)            0
#
#  dense (Dense)               (None, 128)               31490176
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 31,529,034
# Trainable params: 31,529,034
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the Model and Plot loss/accuracy graphs

# %%
# Train the model 
history = model.fit(x_train, y_train, validation_split=0.2, epochs=20, batch_size=32)

# Plot Training and Validation Loss
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Training and Validation Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/20
# 34/34 [==============================] - 127s 4s/step - loss: 2.0363 - accuracy: 0.5195 - val_loss: 0.6555 - val_accuracy: 0.7407
# Epoch 2/20
# 34/34 [==============================] - 63s 2s/step - loss: 0.3383 - accuracy: 0.8875 - val_loss: 0.2614 - val_accuracy: 0.9037
# Epoch 3/20
# 34/34 [==============================] - 86s 3s/step - loss: 0.0521 - accuracy: 0.9879 - val_loss: 0.1021 - val_accuracy: 0.9667
# Epoch 4/20
# 34/34 [==============================] - 82s 2s/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0700 - val_accuracy: 0.9741
# Epoch 5/20
# 34/34 [==============================] - 30s 883ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0763 - val_accuracy: 0.9741
# Epoch 6/20
# 34/34 [==============================] - 102s 3s/step - loss: 8.9006e-04 - accuracy: 1.0000 - val_loss: 0.0772 - val_accuracy: 0.9741
# Epoch 7/20
# 34/34 [==============================] - 99s 3s/step - loss: 6.0886e-04 - accuracy: 1.0000 - val_loss: 0.0777 - val_accuracy: 0.9741
# Epoch 8/20
# 34/34 [==============================] - 87s 3s/step - loss: 4.5301e-04 - accuracy: 1.0000 - val_loss: 0.0753 - val_accuracy: 0.9741
# Epoch 9/20
# 34/34 [==============================] - 45s 1s/step - loss: 3.3794e-04 - accuracy: 1.0000 - val_loss: 0.0774 - val_accuracy: 0.9741
# Epoch 10/20
# 34/34 [==============================] - 114s 3s/step - loss: 2.6345e-04 - accuracy: 1.0000 - val_loss: 0.0795 - val_accuracy: 0.9741
# Epoch 11/20
# 34/34 [==============================] - 113s 3s/step - loss: 2.0956e-04 - accuracy: 1.0000 - val_loss: 0.0781 - val_accuracy: 0.9741
# Epoch 12/20
# 34/34 [==============================] - 67s 2s/step - loss: 1.6938e-04 - accuracy: 1.0000 - val_loss: 0.0793 - val_accuracy: 0.9741
# Epoch 13/20
# 34/34 [==============================] - 21s 604ms/step - loss: 1.3840e-04 - accuracy: 1.0000 - val_loss: 0.0796 - val_accuracy: 0.9741
# Epoch 14/20
# 34/34 [==============================] - 21s 611ms/step - loss: 1.1567e-04 - accuracy: 1.0000 - val_loss: 0.0811 - val_accuracy: 0.9741
# Epoch 15/20
# 34/34 [==============================] - 22s 634ms/step - loss: 9.5744e-05 - accuracy: 1.0000 - val_loss: 0.0817 - val_accuracy: 0.9741
# Epoch 16/20
# 34/34 [==============================] - 22s 652ms/step - loss: 8.1952e-05 - accuracy: 1.0000 - val_loss: 0.0820 - val_accuracy: 0.9741
# Epoch 17/20
# 34/34 [==============================] - 23s 686ms/step - loss: 7.0537e-05 - accuracy: 1.0000 - val_loss: 0.0835 - val_accuracy: 0.9741
# Epoch 18/20
# 34/34 [==============================] - 23s 663ms/step - loss: 6.1766e-05 - accuracy: 1.0000 - val_loss: 0.0838 - val_accuracy: 0.9741
# Epoch 19/20
# 34/34 [==============================] - 23s 664ms/step - loss: 5.4244e-05 - accuracy: 1.0000 - val_loss: 0.0845 - val_accuracy: 0.9704
# Epoch 20/20
# 34/34 [==============================] - 35s 1s/step - loss: 4.8183e-05 - accuracy: 1.0000 - val_loss: 0.0854 - val_accuracy: 0.9704
